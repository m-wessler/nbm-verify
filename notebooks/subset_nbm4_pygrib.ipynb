# %%
import gc
import os
import pygrib
import numpy as np
import xarray as xr

from glob import glob
from functools import partial
from os import makedirs as mkdir
from multiprocessing import get_context
from datetime import datetime, timedelta

os.environ['OMP_NUM_THREAD'] = '1'

# %%
nlat, xlat = 30, 50
nlon, xlon = -130, -100

# %%
def download_grib(url, subset_str, tmp):
    from subprocess import Popen, call
    import requests
    
    filename = url.split('file=')[1].split('&')[0]
    filename = filename.replace('.co.', '.%s.'%subset_str)
        
    if not os.path.isfile(tmp + filename):
        print('Downloading %s\n'%filename)
        
        # r = requests.get(url, allow_redirects=True)
        # open(tmp + filename, 'wb').write(r.content)
        
        # Use call over Popen (blocking)
        cmd = 'wget -O "%s" "%s"'%(tmp + filename, url)
        call(cmd, shell=True)
    
    return filename

# %%
# Set up init to use sys.argv later
init = datetime(2020, 10, 8, 12)
yyyy, mm, dd, hh = init.year, init.month, init.day, init.hour

# %%
base = 'https://nomads.ncep.noaa.gov/cgi-bin/filter_blend.pl?'
var = '&var_APCP=on'
region = '&subregion=&leftlon={:.2f}&rightlon={:.2f}&toplat={:.2f}&bottomlat={:.2f}'.format(nlon, xlon, xlat, nlat)
mdir = '&dir=%2Fblend.{:04d}{:02d}{:02d}%2F{:02d}%2Fqmd'.format(yyyy, mm, dd, hh)

url_list = []

# Need to fix the data processing below to allow for sub24 leads
for fhr in np.arange(24, 180+1, 6):
    file = 'file=blend.t{:02d}z.qmd.f{:03d}.co.grib2'.format(hh, fhr)
    url_list.append(base + file + var + region + mdir)

# %%
tmpdir = '/scratch/general/lustre/u1070830/nbm/tmp/'; mkdir(tmpdir, exist_ok=True)
datadir = '/scratch/general/lustre/u1070830/nbm/'; mkdir(datadir, exist_ok=True)

# %%
download_grib_mp = partial(download_grib, subset_str='WR', tmp=tmpdir)
    
with get_context('fork').Pool(len(url_list)) as p:
    p.map(download_grib_mp, url_list, chunksize=1)
    p.close()
    p.join()
# Out:
# Downloading blend.t12z.qmd.f174.WR.grib2
#
# Downloading blend.t12z.qmd.f132.WR.grib2
#
# Downloading blend.t12z.qmd.f030.WR.grib2
#
# Downloading blend.t12z.qmd.f060.WR.grib2
# Downloading blend.t12z.qmd.f084.WR.grib2
#
# Downloading blend.t12z.qmd.f066.WR.grib2
#
# Downloading blend.t12z.qmd.f096.WR.grib2
# Downloading blend.t12z.qmd.f108.WR.grib2
#
#
#
# Downloading blend.t12z.qmd.f090.WR.grib2
# Downloading blend.t12z.qmd.f138.WR.grib2
#
#
# Downloading blend.t12z.qmd.f168.WR.grib2
# Downloading blend.t12z.qmd.f150.WR.grib2
# Downloading blend.t12z.qmd.f144.WR.grib2
# Downloading blend.t12z.qmd.f162.WR.grib2
#
#
#
#
# Downloading blend.t12z.qmd.f180.WR.grib2
#
# Downloading blend.t12z.qmd.f042.WR.grib2
# Downloading blend.t12z.qmd.f102.WR.grib2
# Downloading blend.t12z.qmd.f048.WR.grib2
#
# Downloading blend.t12z.qmd.f120.WR.grib2
#
#
# Downloading blend.t12z.qmd.f054.WR.grib2
#
# Downloading blend.t12z.qmd.f114.WR.grib2
#
#
# Downloading blend.t12z.qmd.f024.WR.grib2
#
# Downloading blend.t12z.qmd.f036.WR.grib2
#
# Downloading blend.t12z.qmd.f072.WR.grib2
# Downloading blend.t12z.qmd.f126.WR.grib2
#
# Downloading blend.t12z.qmd.f078.WR.grib2
#
# Downloading blend.t12z.qmd.f156.WR.grib2

# %%
flist = sorted(glob(tmpdir + '*.grib2'))

for i, f in enumerate(flist):
    print(i, f)
# Out:
# 0 /scratch/general/lustre/u1070830/nbm/tmp/blend.t12z.qmd.
Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200:Probability of event above upper limit (> 127.0),
#  215:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200:Probability of event above upper limit (> 152.4),
#  216:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  217:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  218:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  219:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  220:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  221:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  222:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  223:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  224:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  225:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  226:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  227:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  228:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  229:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  230:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  231:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  232:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  233:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  234:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  235:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  236:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  237:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  238:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  239:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  240:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  241:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  242:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  243:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  244:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  245:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  246:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  247:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  248:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  249:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  250:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  251:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  252:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  253:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  254:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  255:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  256:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  257:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  258:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  259:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  260:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  261:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  262:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  263:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  264:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  265:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  266:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  267:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  268:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  269:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  270:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  271:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  272:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  273:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  274:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  275:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  276:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  277:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  278:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  279:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  280:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  281:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  282:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  283:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  284:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  285:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  286:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  287:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  288:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  289:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  290:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  291:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  292:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  293:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  294:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  295:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  296:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  297:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  298:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  299:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  300:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  301:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  302:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  303:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  304:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  305:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  306:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  307:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  308:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  309:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  310:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  311:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  312:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  313:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  314:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  315:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 0-24 hrs (accum):from 202010081200,
#  316:Total Precipitation:kg m**-2 (accum):lambert:surface:level 0:fcst time 23-24 hrs (accum):from 202010081200]

# %%
# for msg in msgs:

#     interval = msg['stepRange'].split('-')
#     interval = int(interval[1]) - int(interval[0])

#     if 'Probability of event' in str(msg):    
#             # Probability of event above upper limit (> 0.254) NOT inclusive
#             threshold = round(msg['upperLimit']/25.4, 2)
#             probability.append([msg.values])
#             probability_labels.append([interval, threshold])

#     elif 'percentileValue' in msg.keys():                
#         percentile.append([msg.values])
#         percentile_labels.append([interval, msg['percentileValue']])

#     else:
#         if got_deterministic[interval] == False:
#             deterministic_labels.append(interval)
#             deterministic.append(msg.values)
#             got_deterministic[interval] = True
#         else:
#             pass

# grb.close()
# gc.collect()

# deterministic_labels = np.array(deterministic_labels)
# deterministic_labels = deterministic_labels[np.argsort(deterministic_labels)]
# deterministic = np.array(deterministic)[np.argsort(deterministic_labels)]

# probability = np.array(probability, dtype=object).reshape(-1, lats.shape[0], lats.shape[1])
# probability_labels = np.array(probability_labels)

# percentile = np.array(percentile, dtype=object).reshape(-1, 99, lats.shape[0], lats.shape[1])
# percentile_labels = np.array(percentile_labels)

# deterministic = xr.DataArray(deterministic.astype(np.float32), name='pop',
#                 dims=('interval', 'y', 'x'),
#                 coords={'interval':('interval', deterministic_labels),
#                         'lats':(('y', 'x'), lats), 'lons':(('y', 'x'), lons)})

# pop = xr.DataArray(probability[:3].astype(np.float32), name='pop',
#                 dims=('interval', 'y', 'x'),
#                 coords={'interval':('interval', probability_labels[:3, 0]),
#                         'lats':(('y', 'x'), lats), 'lons':(('y', 'x'), lons)})

# probability = xr.DataArray([probability[2:].astype(np.float32)], name='probability',
#                 dims=('interval', 'threshold', 'y', 'x'),
#                 coords={'interval':('interval', [24]), 'threshold':('threshold', probability_labels[2:,1]),
#                         'lats':(('y', 'x'), lats), 'lons':(('y', 'x'), lons)})

# percentile = xr.DataArray(percentile.astype(np.float32), name='percentile',
#                 dims=('interval', 'percentile', 'y', 'x'),
#                 coords={'interval':('interval', np.unique(percentile_labels[:, 0])), 'percentile':('percentile', range(1, 100)),
#                         'lats':(('y', 'x'), lats), 'lons':(('y', 'x'), lons)})

# ds = xr.Dataset()

# # ds['fhr'] = fhr
# ds['time'] = valid
# ds.attrs['InitTime'] = str(init)

# ds['qpf'] = deterministic
# ds['pop'] = pop
# ds['probx'] = probability
# ds['pqpf'] = percentile
